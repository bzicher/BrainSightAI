# %% [markdown]
# This notebook is to test code and check inputs to model.

# %% [markdown]
# # Imports

# %%
import os
import torch
import brainsight
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from brainsight.dataset import get_data, get_dataloaders_fold
from brainsight.model import CNNClassifier, GRUClassifier, LSTMClassifier

# %% [markdown]
# # Import data

# %%
subject = [5]
data_type = 'emg'
cross_val = 5
channels = 5
dir_data = os.path.join(os.path.normpath(os.getcwd() + os.sep), "..\\data\\processed")

data, labels, cuts = get_data(directory=dir_data, subjects=subject, data_type=data_type,
                              cross_val=cross_val, channels=channels)

# %%
# plot one channel of EMG data
plt.figure(figsize=(10, 5))
plt.plot(data[10, 0, :])
plt.xticks(np.arange(0, 2049, 256), np.arange(0, 1001, 125))
plt.title('One EMG channel from one trial')
plt.xlabel('Time (ms)')
plt.ylabel('Amplitude')
plt.show()

# %%
subject = [5]
data_type = 'eeg'
cross_val = 5
channels = 5
dir_data = os.path.join(os.path.normpath(os.getcwd() + os.sep), "..\\data\\processed")

data, labels, cuts = get_data(directory=dir_data, subjects=subject, data_type=data_type,
                              cross_val=cross_val, channels=channels)

# %%
# plot one channel of EEG data
plt.figure(figsize=(10, 5))
plt.plot(data[15, 0, :])
plt.xticks(np.arange(0, 2049, 256), np.arange(0, 1001, 125))
plt.title('One EEG channel from one trial')
plt.xlabel('Time (ms)')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')
